# %%
import joblib

# %%
pipe = joblib.load('pipe.pkl')

# %% [markdown]
# ### 이 고객은 구매를 할까요 말까요 나이는 37세, 연봉은 43000달러

# %%
data = [ { 'Age' : 37, 'salary': 43000 } ]

# %%
import pandas as pd

# %%
new_data = pd.DataFrame(data)

# %%
new_data
# Out:
#    Age  salary
# 0   37   43000

# %%
pipe.predict(new_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pipe.predict(new_data)
#
# File ~\miniconda3\envs\yh\lib\site-packages\sklearn\pipeline.py:788, in Pipeline.predict(self, X, **params)
#     786 if not _routing_enabled():
#     787     for _, name, transform in self._iter(with_final=False):
# --> 788         Xt = transform.transform(Xt)
#     789     return self.steps[-1][1].predict(Xt, **params)
#     791 # metadata routing enabled
#
# File ~\miniconda3\envs\yh\lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
# ...
